# %% [markdown]
# # Sample: Data-informed strategy
#
# A minimal notebook for The AI Strategist. Use this as a starting point for analyses on AI, corporate strategy, and value creation.
#
# Replace the content below with your own code and narrative.

# %%
import pandas as pd

# Placeholder: your analysis here
pd.Series(["strategy", "data", "value"]).to_frame(name="focus")
